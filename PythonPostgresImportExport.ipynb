# %%
import pandas as pd
import csv
import os
from sqlalchemy import create_engine
from config import pg_pw
from config import pg_user

# %%
# ====== Connection ======
# Connecting to PostgreSQL by providing a sqlachemy engine
engine = create_engine('postgresql://'+pg_user+':'+pg_pw+'@127.0.0.1:5432/PH-EmployeeDB')

# %%
# ====== Reading table ======
# Reading PostgreSQL table into a pandas DataFrame
retiring_titles_df = pd.read_sql('SELECT * FROM retiring_titles', engine)
retiring_titles_df
# Out:
#    count               title
# 0  29415     Senior Engineer
# 1  28255        Senior Staff
# 2  14221            Engineer
# 3  12242               Staff
# 4   4502    Technique Leader
# 5   1761  Assistant Engineer
# 6      2             Manager

# %%
# Write out DateFrame
csv_file = os.path.join("data","retiring_titles.csv")
retiring_titles_df.to_csv(csv_file)

# %%
# ====== Reading table ======
# Reading PostgreSQL table into a pandas DataFrame
retiring_titles_df = pd.read_sql('SELECT * FROM mentorship_eligibility', engine)
retiring_titles_df
# Out:
#       emp_no first_name    last_name  birth_date   from_date     to_date  \
# 0      10095     Hilari       Morton  1965-01-03  1994-03-10  9999-01-01
# 1      10122       Ohad     Esposito  1965-01-19  1998-08-06  9999-01-01
# 2      10291    Dipayan  Seghrouchni  1965-01-23  1987-03-30  9999-01-01
# 3      10476      Kokou       Iisaka  1965-01-01  1987-09-20  9999-01-01
# 4      10663     Teunis      Noriega  1965-01-09  1999-02-12  9999-01-01
# ...      ...        ...          ...         ...         ...         ...
# 1544  498845   Arumugam         Pelc  1965-01-09  1999-11-13  9999-01-01
# 1545  498955    Nechama      Kandlur  1965-01-13  1995-01-16  9999-01-01
# 1546  499194      Padma    Delgrange  1965-01-29  1999-08-27  9999-01-01
# 1547  499260      Danae      Honglei  1965-01-11  1998-09-14  9999-01-01
# 1548  499495     Baoqiu       Kakkar  1965-01-14  1999-08-30  9999-01-01
#
#                  title
# 0         Senior Staff
# 1     Technique Leader
# ...

# %%
# Write out DateFrame
csv_file = os.path.join("data","mentorship_eligibility.csv")
retiring_titles_df.to_csv(csv_file)

# %%
# ====== Reading table ======
# Reading PostgreSQL table into a pandas DataFrame
retiring_titles_df = pd.read_sql('SELECT * FROM mentorship_eligibility_titles', engine)
retiring_titles_df
# Out:
#    count               title
# 0    569        Senior Staff
# 1    529     Senior Engineer
# 2    190            Engineer
# 3    155               Staff
# 4     77    Technique Leader
# 5     29  Assistant Engineer

# %%
# Write out DateFrame
csv_file = os.path.join("data","mentorship_eligibility_titles.csv")
retiring_titles_df.to_csv(csv_file)
